# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('/content/Tesla_dataset.csv',index_col='Date',parse_dates=True)
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
data.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3505 entries, 2010-06-29 to 2024-05-31
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       3505 non-null   float64
#  1   High       3505 non-null   float64
#  2   Low        3505 non-null   float64
#  3   Close      3505 non-null   float64
#  4   Adj Close  3505 non-null   float64
#  5   Volume     3505 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 191.7 KB

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  3505.000000  3505.000000  3505.000000  3505.000000  3505.000000
# mean     73.941523    75.549608    72.209440    73.916853    73.916853
# std     101.999877   104.246204    99.526282   101.916537   101.916537
# min       1.076000     1.108667     0.998667     1.053333     1.053333
# 25%      11.345333    11.546667    11.010000    11.310667    11.310667
# 50%      17.302000    17.557333    16.969334    17.319332    17.319332
# 75%     146.919998   149.630005   142.833328   147.050003   147.050003
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  3.505000e+03
# mean   9.688131e+07
# std    7.897872e+07
# min    1.777500e+06
# 25%    4.716300e+07
# 50%    8.214300e+07
# 75%    1.226595e+08
# max    9.140820e+08

# %%
data.shape
# Out:
# (3505, 6)

# %%
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
plt.figure(figsize=(15,6))
plt.plot(data['Open'],color='r')
plt.plot(data['Close'])
plt.legend(['Open Price','Close price'])
plt.title('Close Price and Open Price History')
plt.xlabel('Open Price Of the Shares')
plt.ylabel('Close Price of the Shares')
plt.show()

# %%
plt.figure(figsize=(15,6))
plt.plot(data['Volume'],color='g')
plt.title('Volume History')
plt.legend(['Shares of Volume'])
plt.title('Volume History')
plt.xlabel(None)
plt.ylabel('Volume')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,15))
data['Volume'].pct_change().hist(bins=50)
plt.title('Volume Distribution')
plt.xlabel('Volume')
plt.ylabel('Frequency')
plt.show()
plt.show()

# %%
plt.figure(figsize=(15,6))
data['Adj Close'].pct_change().hist(bins=50)
plt.title('Adj Close Distribution')
plt.xlabel('Adj Close')
plt.ylabel('Frequency')
plt.show()

# %%
data.drop_duplicates(inplace=True)
data.head()
# Out:
#                 Open      High       Low     Close  Adj Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667   1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667   1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000   1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000   1.074000  103003500

# %%
data=data.drop(['Adj Close'],axis=1)
data.head()
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2010-06-29  1.266667  1.666667  1.169333  1.592667  281494500
# 2010-06-30  1.719333  2.028000  1.553333  1.588667  257806500
# 2010-07-01  1.666667  1.728000  1.351333  1.464000  123282000
# 2010-07-02  1.533333  1.540000  1.247333  1.280000   77097000
# 2010-07-06  1.333333  1.333333  1.055333  1.074000  103003500

# %%
x=data.drop(['Close'],axis=1)
y=data['Close']

# %%
x.shape
# Out:
# (3505, 4)

# %%
y.shape
# Out:
# (3505,)

# %%
timesplit= TimeSeriesSplit(n_splits=5)
for train_index, test_index in timesplit.split(x):
        X_train, X_test = x[:len(train_index)], x[len(train_index): (len(train_index)+len(test_index))]
        y_train, y_test = y[:len(train_index)].values.ravel(), y[len(train_index): (len(train_index)+len(test_index))].values.ravel()

# %%
X_test.ndim
# Out:
# 2

# %%
X_train
# Out:
#                   Open        High         Low     Volume
# Date
# 2010-06-29    1.266667    1.666667    1.169333  281494500
# 2010-06-30    1.719333    2.028000    1.553333  257806500
# 2010-07-01    1.666667    1.728000    1.351333  123282000
# 2010-07-02    1.533333    1.540000    1.247333   77097000
# 2010-07-06    1.333333    1.333333    1.055333  103003500
# ...                ...         ...         ...        ...
# 2022-01-27  311.119995  311.796661  276.333344  147109500
# 2022-01-28  277.186676  285.833344  264.003326  134789100
# 2022-01-31  290.903320  312.663330  287.350006  104436000
# 2022-02-01  311.736664  314.566681  301.666656   73138200
# 2022-02-02  309.393341  310.500000  296.470001   66792900
#
# [2921 rows x 4 columns]

# %%
from sklearn.preprocessing import MinMaxScaler

# Instantiate scalers
scaler_X = MinMaxScaler()
scaler_Y = MinMaxScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
y_train_scaled = scaler_Y.fit_transform(y_train.reshape(-1, 1))
X_test_scaled = scaler_X.transform(X_test)
y_test_scaled = scaler_Y.transform(y_test.reshape(-1, 1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-401-59974005252e> in <cell line: 6>()
#       4 scaler_X = MinMaxScaler()
#       5 scaler_Y = MinMaxScaler()
# ----> 6 X_train_scaled = scaler_X.fit_transform(X_train)
#       7 y_train_scaled = scaler_Y.fit_transform(y_train.reshape(-1, 1))
#       8 X_test_scaled = scaler_X.transform(X_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     155     @wraps(f)
#     156     def wrapped(self, X, *args, **kwargs):
# --> 157         data_to_wrap = f(self, X, *args, **kwargs)
#     158         if isinstance(data_to_wrap, tuple):
#     159             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     914         if y is None:
# ...

# %%
x_train.shape
# Out:
# (2804, 4)

# %%
y_test.shape
# Out:
# (584, 1)

# %%
y_train.ndim
# Out:
# 2

# %%
x_train.ndim
# Out:
# 2

# %%
type(x_train)
# Out:
# numpy.ndarray

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
x_train.ndim
# Out:
# 2

# %%
y_train.ndim
# Out:
# 2

# %%
from tensorflow.keras.models import Sequential
from keras.layers import Input, Dense, Flatten, Dropout, LSTM

# %%
model=Sequential()

# %%
time_steps=1
trainX =np.array(X_train)
testX =np.array(X_test)
feature = 4
X_train = trainX.reshape(int(X_train.shape[0]/time_steps), time_steps, feature)
X_test = testX.reshape(int(X_test.shape[0]/time_steps), time_steps, feature)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense

# Assuming 'feature' is the number of input features (you'll need to define this)
  # Replace with the actual number of features

model = Sequential()
model.add(LSTM(128, return_sequences=True, input_shape=(1, feature), activation='tanh'))
model.add(Dropout(0.2))
model.add(LSTM(64, activation='tanh'))
model.add(Dropout(0.2))
model.add(Dense(1, activation='linear'))

model.compile(optimizer='adam', loss='mse', metrics=['mse'])

# %%
model.summary()
# Out:
# Model: "sequential_17"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  lstm_41 (LSTM)              (None, 1, 128)            68096
#
#  dropout_30 (Dropout)        (None, 1, 128)            0
#
#  lstm_42 (LSTM)              (None, 64)                49408
#
#  dropout_31 (Dropout)        (None, 64)                0
#
#  dense_7 (Dense)             (None, 1)                 65
#
# ...
# Total params: 117569 (459.25 KB)
# Trainable params: 117569 (459.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
evaluate=model.fit(X_train, y_train, validation_data=(X_test,y_test), batch_size=8, epochs=300)
# Out:
# Epoch 1/300
# 366/366 [==============================] - 3s 9ms/step - loss: 3.6703e-04 - mse: 3.6703e-04 - val_loss: 5.1300e-04 - val_mse: 5.1300e-04
# Epoch 2/300
# 366/366 [==============================] - 2s 6ms/step - loss: 3.7521e-04 - mse: 3.7521e-04 - val_loss: 2.4946e-04 - val_mse: 2.4946e-04
# Epoch 3/300
# 366/366 [==============================] - 2s 6ms/step - loss: 3.3941e-04 - mse: 3.3941e-04 - val_loss: 3.0790e-04 - val_mse: 3.0790e-04
# Epoch 4/300
# 366/366 [==============================] - 2s 6ms/step - loss: 3.3766e-04 - mse: 3.3766e-04 - val_loss: 4.5239e-04 - val_mse: 4.5239e-04
# Epoch 5/300
# 366/366 [==============================] - 2s 6ms/step - loss: 3.3173e-04 - mse: 3.3173e-04 - val_loss: 3.8655e-04 - val_mse: 3.8655e-04
# Epoch 6/300
# 366/366 [==============================] - 3s 8ms/step - loss: 3.5299e-04 - mse: 3.5299e-04 - val_loss: 1.9887e-04 - val_mse: 1.9887e-04
# Epoch 7/300
# ...

# %%
X_train.shape
# Out:
# (2921, 1, 4)

# %%
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)

# Adjust the target labels (y_train) to match the reshaped input data
y_train = y_train[time_steps-1:]  # Remove the first 'time_steps - 1' labels

# Reshape the input data
X_train = trainX.reshape(int(trainX.shape[0] - time_steps + 1), time_steps, feature)
# Out:
# Shape of X_train: (2921, 1, 4)
# Shape of y_train: (2921, 1)

# %%
# Assuming 'time_steps' and 'feature' are defined
import numpy as np # Import numpy for array manipulation

y_train = np.array(y_train[time_steps - 1:]) # Convert y_train to numpy array
X_train = trainX.reshape(int(trainX.shape[0] - time_steps + 1), time_steps, feature)

y_test = np.array(y_test[time_steps - 1:]) # Convert y_test to numpy array
X_test = testX.reshape(int(testX.shape[0] - time_steps + 1), time_steps, feature)

# Check if the number of samples match after adjustment
print("Shape of X_train:", X_train.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_test:", y_test.shape)

# Proceed with model fitting if the shapes align
if X_train.shape[0] == y_train.shape[0] and X_test.shape[0] == y_test.shape[0]:
    evaluate = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
else:
    print("Error: Number of samples in input and target data do not match. Recheck data preprocessing.")
# Out:
# Shape of X_train: (2921, 1, 4)
# Shape of y_train: (2921, 1)
# Shape of X_test: (584, 1, 4)
# Shape of y_test: (584, 1)
# Epoch 1/100
# 92/92 [==============================] - 2s 17ms/step - loss: 2.3345e-04 - mse: 2.3345e-04 - val_loss: 1.3961e-04 - val_mse: 1.3961e-04
# Epoch 2/100
# 92/92 [==============================] - 1s 7ms/step - loss: 2.3050e-04 - mse: 2.3050e-04 - val_loss: 1.0257e-04 - val_mse: 1.0257e-04
# Epoch 3/100
# 92/92 [==============================] - 1s 8ms/step - loss: 2.4936e-04 - mse: 2.4936e-04 - val_loss: 8.5986e-05 - val_mse: 8.5986e-05
# Epoch 4/100
# 92/92 [==============================] - 1s 8ms/step - loss: 2.1481e-04 - mse: 2.1481e-04 - val_loss: 9.4997e-05 - val_mse: 9.4997e-05
# Epoch 5/100
# 92/92 [==============================] - 1s 7ms/step - loss: 2.1032e-04 - mse: 2.1032e-04 - val_loss: 1.2277e-04 - val_mse: 1.2277e-04
# Epoch 6/100
# ...

# %%
 evaluate = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 92/92 [==============================] - 1s 8ms/step - loss: 2.1432e-04 - mse: 2.1432e-04 - val_loss: 1.8134e-04 - val_mse: 1.8134e-04
# Epoch 2/100
# 92/92 [==============================] - 1s 7ms/step - loss: 2.3301e-04 - mse: 2.3301e-04 - val_loss: 4.2065e-04 - val_mse: 4.2065e-04
# Epoch 3/100
# 92/92 [==============================] - 1s 7ms/step - loss: 2.8133e-04 - mse: 2.8133e-04 - val_loss: 2.1136e-04 - val_mse: 2.1136e-04
# Epoch 4/100
# 92/92 [==============================] - 1s 7ms/step - loss: 2.1484e-04 - mse: 2.1484e-04 - val_loss: 2.4184e-04 - val_mse: 2.4184e-04
# Epoch 5/100
# 92/92 [==============================] - 1s 7ms/step - loss: 2.1763e-04 - mse: 2.1763e-04 - val_loss: 1.7138e-04 - val_mse: 1.7138e-04
# Epoch 6/100
# 92/92 [==============================] - 1s 10ms/step - loss: 2.1809e-04 - mse: 2.1809e-04 - val_loss: 2.1519e-04 - val_mse: 2.1519e-04
# Epoch 7/100
# ...

# %%
x_test = []
y_test = []
for i in range(60, len(X_test)): # Use 'test_data' for length calculation
    x_test.append(test_data[i-60:i, 0]) # Append to the list 'x_test'
    y_test.append(test_data[i, 0])
x_test, y_test = np.array(x_test), np.array(y_test) # Convert lists to NumPy arrays
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) # Reshape should work now
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-380-801e44a05bfe> in <cell line: 7>()
#       5     y_test.append(test_data[i, 0])
#       6 x_test, y_test = np.array(x_test), np.array(y_test) # Convert lists to NumPy arrays
# ----> 7 x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1)) # Reshape should work now
#
# IndexError: tuple index out of range

# %%
y_pred=model.predict
# Out:
# 19/19 [==============================] - 1s 3ms/step

# %%
X_test
# Out:
# array([[[0.71376287, 0.75286334, 0.7228345 , 0.08448725]],
#
#        [[0.72612497, 0.75246012, 0.72336994, 0.0787543 ]],
#
#        [[0.74770584, 0.76154767, 0.74111287, 0.06490925]],
#
#        ...,
#
#        [[0.42182391, 0.42826914, 0.42734125, 0.05810023]],
#
#        [[0.43252095, 0.43920319, 0.43092447, 0.08331352]],
#
#        [[0.43232601, 0.43351848, 0.42706946, 0.07183687]]])

# %%
y_pred_actual=scaler.inverse_transform(y_pred)
y_test_actual=scaler.inverse_transform(y_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-360-51bc4bf6bb1b> in <cell line: 1>()
# ----> 1 y_pred_actual=scaler.inverse_transform(y_pred)
#       2 y_test_actual=scaler.inverse_transform(y_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_data.py in inverse_transform(self, X)
#     546         )
#     547
# --> 548         X -= self.min_
#     549         X /= self.scale_
#     550         return X
#
# ValueError: non-broadcastable output operand with shape (584,1) doesn't match the broadcast shape (584,4)

# %%
from datetime import timedelta

# %%
def insert_end(Xin, new_input):
    timestep = 60
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
X_test.ndim
# Out:
# 3

# %%
X_test
# Out:
# array([[[0.71376287, 0.75286334, 0.7228345 , 0.08448725]],
#
#        [[0.72612497, 0.75246012, 0.72336994, 0.0787543 ]],
#
#        [[0.74770584, 0.76154767, 0.74111287, 0.06490925]],
#
#        ...,
#
#        [[0.42182391, 0.42826914, 0.42734125, 0.05810023]],
#
#        [[0.43252095, 0.43920319, 0.43092447, 0.08331352]],
#
#        [[0.43232601, 0.43351848, 0.42706946, 0.07183687]]])

# %%
future = 60
forecast = []
def insert_end(Xin, new_input):
    timestep = Xin.shape[1]  # Get the actual timestep from the shape of Xin
    for i in range(timestep - 1):
        Xin[:, i, :] = Xin[:, i+1, :]
    Xin[:, timestep - 1, :] = new_input
    return Xin

# %%
future =60
forcast = []
Xin = X_test[-1 :, :, :]
time = []
for i in range(0, future):
    out = model.predict(Xin, batch_size=5)
    forcast.append(out[0, 0])
    print(forcast)
    Xin = insert_end(Xin, out[0, 0])
    time.append(pd.to_datetime(data.index[-1]) + timedelta(days=i))
# Out:
# 1/1 [==============================] - 0s 22ms/step
# [0.43359575]
# 1/1 [==============================] - 0s 21ms/step
# [0.43359575, 0.4469979]
# 1/1 [==============================] - 0s 28ms/step
# [0.43359575, 0.4469979, 0.4612942]
# 1/1 [==============================] - 0s 26ms/step
# [0.43359575, 0.4469979, 0.4612942, 0.47654584]
# 1/1 [==============================] - 0s 20ms/step
# [0.43359575, 0.4469979, 0.4612942, 0.47654584, 0.49280983]
# 1/1 [==============================] - 0s 23ms/step
# [0.43359575, 0.4469979, 0.4612942, 0.47654584, 0.49280983, 0.51013446]
# 1/1 [==============================] - 0s 30ms/step
# [0.43359575, 0.4469979, 0.4612942, 0.47654584, 0.49280983, 0.51013446, 0.5285533]
# 1/1 [==============================] - 0s 21ms/step
# [0.43359575, 0.4469979, 0.4612942, 0.47654584, 0.49280983, 0.51013446, 0.5285533, 0.5480771]
# 1/1 [==============================] - 0s 20ms/step
# ...

# %%
time
# Out:
# [Timestamp('2024-05-31 00:00:00'),
#  Timestamp('2024-06-01 00:00:00'),
#  Timestamp('2024-06-02 00:00:00'),
#  Timestamp('2024-06-03 00:00:00'),
#  Timestamp('2024-06-04 00:00:00'),
#  Timestamp('2024-06-05 00:00:00'),
#  Timestamp('2024-06-06 00:00:00'),
#  Timestamp('2024-06-07 00:00:00'),
#  Timestamp('2024-06-08 00:00:00'),
#  Timestamp('2024-06-09 00:00:00'),
#  Timestamp('2024-06-10 00:00:00'),
#  Timestamp('2024-06-11 00:00:00'),
#  Timestamp('2024-06-12 00:00:00'),
#  Timestamp('2024-06-13 00:00:00'),
#  Timestamp('2024-06-14 00:00:00'),
#  Timestamp('2024-06-15 00:00:00'),
#  Timestamp('2024-06-16 00:00:00'),
#  Timestamp('2024-06-17 00:00:00'),
#  Timestamp('2024-06-18 00:00:00'),
#  Timestamp('2024-06-19 00:00:00'),
#  Timestamp('2024-06-20 00:00:00'),
#  Timestamp('2024-06-21 00:00:00'),
#  Timestamp('2024-06-22 00:00:00'),
#  Timestamp('2024-06-23 00:00:00'),
#  Timestamp('2024-06-24 00:00:00'),
#  Timestamp('2024-06-25 00:00:00'),
#  Timestamp('2024-06-26 00:00:00'),
# ...

# %%
scaler = MinMaxScaler()
# Fit the scaler to your training data (replace 'data' with your training data)
scaler.fit(data[['Close']])

forcasted_output = np.asarray(forcast)
forcasted_output = forcasted_output.reshape(-1, 1)
forcasted_output = scaler.inverse_transform(forcasted_output)

# %%
forcasted_output = pd.DataFrame(forcasted_output)
date = pd.DataFrame(time)
df_result = pd.concat([date,forcasted_output], axis=1)
df_result.columns = "Date", "Forecasted"

# %%
df_result
# Out:
#          Date  Forecasted
# 0  2024-05-31  178.357864
# 1  2024-06-01  183.838226
# 2  2024-06-02  189.684219
# 3  2024-06-03  195.920868
# 4  2024-06-04  202.571487
# 5  2024-06-05  209.655823
# 6  2024-06-06  217.187607
# 7  2024-06-07  225.171204
# 8  2024-06-08  233.597656
# 9  2024-06-09  242.440109
# 10 2024-06-10  251.648712
# 11 2024-06-11  261.146759
# 12 2024-06-12  270.827820
# 13 2024-06-13  280.556519
# 14 2024-06-14  290.173401
# 15 2024-06-15  299.505066
# 16 2024-06-16  308.378784
# 17 2024-06-17  316.638977
# 18 2024-06-18  324.162598
# 19 2024-06-19  330.869812
# 20 2024-06-20  336.728088
# 21 2024-06-21  341.748627
# 22 2024-06-22  345.978455
# 23 2024-06-23  349.489258
# 24 2024-06-24  352.365967
# 25 2024-06-25  354.697815
# 26 2024-06-26  356.571136
# 27 2024-06-27  358.065155
# 28 2024-06-28  359.249542
# 29 2024-06-29  360.184113
# 30 2024-06-30  360.918762
# 31 2024-07-01  361.494537
# 32 2024-07-02  361.944733
# 33 2024-07-03  362.296082
# ...

# %%
plt.figure(figsize=(15,6))
plt.plot(df_result['Date'])
plt.plot(df_result['Forecasted'])
plt.tight_layout()
plt.show()

# %%
# @title Forecasted

from matplotlib import pyplot as plt
df_result['Forecasted'].plot(kind='line', figsize=(8, 4), title='Forecasted')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# @title Forecasted

from matplotlib import pyplot as plt
df_result['Forecasted'].plot(kind='hist', bins=20, title='Forecasted')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
plt.figure(figsize=(8,8))
plt.title('Tesla Close Stock Price Forecasting For Next 60 days')
plt.xlabel('Date', fontsize=18)
plt.ylabel('Close' ,fontsize=18)
plt.plot(data['Close'])
plt.grid()
plt.plot(df_result.set_index('Date')[['Forecasted']])
